# %%
import requests
import itertools

# Define the Flask endpoint
url = "http://127.0.0.1:5000/predict"  # Replace with your deployed app URL if needed

# Define the column names (features)
column_names = [
    "itching", "skin_rash", "nodal_skin_eruptions", "continuous_sneezing", "shivering", "chills", "joint_pain",
    "stomach_pain", "acidity", "ulcers_on_tongue", "muscle_wasting", "vomiting", "burning_micturition",
    "spotting_urination", "fatigue", "weight_gain", "anxiety", "cold_hands_and_feets", "mood_swings",
    "weight_loss", "restlessness", "lethargy", "patches_in_throat", "irregular_sugar_level", "cough",
    "high_fever", "sunken_eyes", "breathlessness", "sweating", "dehydration", "indigestion", "headache",
    # Add other feature names here as needed...
]

# Helper function to send POST request with feature combinations
def send_request(active_features):
    # Generate input form data (Yes/No for all features)
    form_data = {feature: 'Yes' if feature in active_features else 'No' for feature in column_names}
    
    # Send the POST request to Flask app
    try:
        response = requests.post(url, data=form_data)
        if response.status_code == 200:
            print(f"Active Features: {active_features} --> Prediction: {response.json()}")
        else:
            print(f"Failed for {active_features} --> Status Code: {response.status_code}")
    except Exception as e:
        print(f"Error testing {active_features}: {e}")

# Test all combinations of 1, 2, or 3 features
for r in range(1, 4):  # r = 1 (single features), 2 (pairs), 3 (triplets)
    feature_combinations = itertools.combinations(column_names, r)
    for combo in feature_combinations:
        send_request(combo)
# Out:
# Active Features: ('itching',) --> Prediction: {'dl_prediction': 'Chronic Cholestasis', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('skin_rash',) --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions',) --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('continuous_sneezing',) --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering',) --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('chills',) --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Allergy'}
# Active Features: ('joint_pain',) --> Prediction: {'dl_prediction': 'Osteoarthritis', 'rf_prediction': 'Psoriasis'}
# Active Features: ('stomach_pain',) --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('acidity',) --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('ulcers_on_tongue',) --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('muscle_wasting',) --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('vomiting',) --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('burning_micturition',) --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('spotting_urination',) --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('fatigue',) --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Varicose Veins'}
# Active Features: ('weight_gain',) --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Dimorphic Hemmorhoids (piles)'}
# Active Features: ('anxiety',) --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'Dimorphic Hemmorhoids (piles)'}
# Active Features: ('cold_hands_and_feets',) --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Dimorphic Hemmorhoids (piles)'}
# Active Features: ('mood_swings',) --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Dimorphic Hemmorhoids (piles)'}
# Active Features: ('weight_loss',) --> Prediction: {'dl_prediction': 'Jaundice', 'rf_prediction': 'Jaundice'}
# Active Features: ('restlessness',) --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Dimorphic Hemmorhoids (piles)'}
# Active Features: ('lethargy',) --> Prediction: {'dl_prediction': 'Osteoarthritis', 'rf_prediction': 'Dimorphic Hemmorhoids (piles)'}
# Active Features: ('patches_in_throat',) --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('irregular_sugar_level',) --> Prediction: {'dl_prediction': 'Diabetes ', 'rf_prediction': 'Diabetes '}
# Active Features: ('cough',) --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Bronchial Asthma'}
# Active Features: ('high_fever',) --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'AIDS'}
# Active Features: ('sunken_eyes',) --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('breathlessness',) --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('sweating',) --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('dehydration',) --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('indigestion',) --> Prediction: {'dl_prediction': 'Osteoarthritis', 'rf_prediction': 'Peptic Ulcer Disease'}
# Active Features: ('headache',) --> Prediction: {'dl_prediction': 'Hypertension ', 'rf_prediction': 'Paralysis (brain hemorrhage)'}
# Active Features: ('itching', 'skin_rash') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'nodal_skin_eruptions') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'continuous_sneezing') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('itching', 'shivering') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('itching', 'chills') --> Prediction: {'dl_prediction': 'Chronic Cholestasis', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'joint_pain') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'stomach_pain') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('itching', 'acidity') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'ulcers_on_tongue') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'muscle_wasting') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('itching', 'vomiting') --> Prediction: {'dl_prediction': 'Chronic Cholestasis', 'rf_prediction': 'Chronic Cholestasis'}
# Active Features: ('itching', 'burning_micturition') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('itching', 'spotting_urination') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('itching', 'fatigue') --> Prediction: {'dl_prediction': 'Jaundice', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'weight_gain') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'anxiety') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'mood_swings') --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'weight_loss') --> Prediction: {'dl_prediction': 'Jaundice', 'rf_prediction': 'Jaundice'}
# Active Features: ('itching', 'restlessness') --> Prediction: {'dl_prediction': 'Chronic Cholestasis', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'lethargy') --> Prediction: {'dl_prediction': 'Vertigo', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('itching', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Diabetes ', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'cough') --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'high_fever') --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('itching', 'breathlessness') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'sweating') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('itching', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('itching', 'indigestion') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('itching', 'headache') --> Prediction: {'dl_prediction': 'Chronic Cholestasis', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('skin_rash', 'nodal_skin_eruptions') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('skin_rash', 'continuous_sneezing') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('skin_rash', 'shivering') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('skin_rash', 'chills') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Allergy'}
# Active Features: ('skin_rash', 'joint_pain') --> Prediction: {'dl_prediction': 'Acne', 'rf_prediction': 'Psoriasis'}
# Active Features: ('skin_rash', 'stomach_pain') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('skin_rash', 'acidity') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('skin_rash', 'ulcers_on_tongue') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('skin_rash', 'muscle_wasting') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('skin_rash', 'vomiting') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Acne'}
# Active Features: ('skin_rash', 'burning_micturition') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('skin_rash', 'spotting_urination') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('skin_rash', 'fatigue') --> Prediction: {'dl_prediction': 'Acne', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('skin_rash', 'weight_gain') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('skin_rash', 'anxiety') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'Acne'}
# Active Features: ('skin_rash', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('skin_rash', 'mood_swings') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('skin_rash', 'weight_loss') --> Prediction: {'dl_prediction': 'Jaundice', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('skin_rash', 'restlessness') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('skin_rash', 'lethargy') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('skin_rash', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('skin_rash', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Diabetes ', 'rf_prediction': 'Acne'}
# Active Features: ('skin_rash', 'cough') --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Acne'}
# Active Features: ('skin_rash', 'high_fever') --> Prediction: {'dl_prediction': 'Acne', 'rf_prediction': 'Impetigo'}
# Active Features: ('skin_rash', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('skin_rash', 'breathlessness') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('skin_rash', 'sweating') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('skin_rash', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('skin_rash', 'indigestion') --> Prediction: {'dl_prediction': 'Peptic Ulcer Disease', 'rf_prediction': 'Acne'}
# Active Features: ('skin_rash', 'headache') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Paralysis (brain hemorrhage)'}
# Active Features: ('nodal_skin_eruptions', 'continuous_sneezing') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Allergy'}
# Active Features: ('nodal_skin_eruptions', 'shivering') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'chills') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'joint_pain') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'stomach_pain') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'acidity') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'ulcers_on_tongue') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'muscle_wasting') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'AIDS'}
# Active Features: ('nodal_skin_eruptions', 'vomiting') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'burning_micturition') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'spotting_urination') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'fatigue') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'weight_gain') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'anxiety') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'mood_swings') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'weight_loss') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'restlessness') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'lethargy') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'patches_in_throat') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'AIDS'}
# Active Features: ('nodal_skin_eruptions', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'cough') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'high_fever') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'breathlessness') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'sweating') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Heart Attack'}
# Active Features: ('nodal_skin_eruptions', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('nodal_skin_eruptions', 'indigestion') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('nodal_skin_eruptions', 'headache') --> Prediction: {'dl_prediction': 'Fungal Infection', 'rf_prediction': 'Fungal Infection'}
# Active Features: ('continuous_sneezing', 'shivering') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'chills') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'joint_pain') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'stomach_pain') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'acidity') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'ulcers_on_tongue') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'muscle_wasting') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'vomiting') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'burning_micturition') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'spotting_urination') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'fatigue') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'weight_gain') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'anxiety') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'mood_swings') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'weight_loss') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'restlessness') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'lethargy') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'cough') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'high_fever') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'breathlessness') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'sweating') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('continuous_sneezing', 'indigestion') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('continuous_sneezing', 'headache') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'chills') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'joint_pain') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'stomach_pain') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'acidity') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'ulcers_on_tongue') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'muscle_wasting') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'AIDS'}
# Active Features: ('shivering', 'vomiting') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'burning_micturition') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'spotting_urination') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'fatigue') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'weight_gain') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'anxiety') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'mood_swings') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'weight_loss') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'restlessness') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'lethargy') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('shivering', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'cough') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'high_fever') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('shivering', 'breathlessness') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'sweating') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Heart Attack'}
# Active Features: ('shivering', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('shivering', 'indigestion') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('shivering', 'headache') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'joint_pain') --> Prediction: {'dl_prediction': 'Malaria', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'stomach_pain') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'acidity') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'ulcers_on_tongue') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'muscle_wasting') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('chills', 'vomiting') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'burning_micturition') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('chills', 'spotting_urination') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'fatigue') --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_gain') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'anxiety') --> Prediction: {'dl_prediction': 'Hypoglycemia', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'mood_swings') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_loss') --> Prediction: {'dl_prediction': 'Jaundice', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'restlessness') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'lethargy') --> Prediction: {'dl_prediction': 'Paralysis (brain hemorrhage)', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('chills', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Diabetes ', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'cough') --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'high_fever') --> Prediction: {'dl_prediction': 'Malaria', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'breathlessness') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('chills', 'sweating') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('chills', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'indigestion') --> Prediction: {'dl_prediction': 'Malaria', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'headache') --> Prediction: {'dl_prediction': 'Malaria', 'rf_prediction': 'Allergy'}
# Active Features: ('joint_pain', 'stomach_pain') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('joint_pain', 'acidity') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('joint_pain', 'ulcers_on_tongue') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('joint_pain', 'muscle_wasting') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('joint_pain', 'vomiting') --> Prediction: {'dl_prediction': 'Hepatitis D', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('joint_pain', 'burning_micturition') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('joint_pain', 'spotting_urination') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('joint_pain', 'fatigue') --> Prediction: {'dl_prediction': 'Hepatitis D', 'rf_prediction': 'Psoriasis'}
# Active Features: ('joint_pain', 'weight_gain') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Psoriasis'}
# Active Features: ('joint_pain', 'anxiety') --> Prediction: {'dl_prediction': 'Hypoglycemia', 'rf_prediction': 'Psoriasis'}
# Active Features: ('joint_pain', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Psoriasis'}
# Active Features: ('joint_pain', 'mood_swings') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Psoriasis'}
# Active Features: ('joint_pain', 'weight_loss') --> Prediction: {'dl_prediction': 'Jaundice', 'rf_prediction': 'Psoriasis'}
# Active Features: ('joint_pain', 'restlessness') --> Prediction: {'dl_prediction': 'Diabetes ', 'rf_prediction': 'Psoriasis'}
# Active Features: ('joint_pain', 'lethargy') --> Prediction: {'dl_prediction': 'Chickenpox', 'rf_prediction': 'Psoriasis'}
# Active Features: ('joint_pain', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('joint_pain', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Diabetes ', 'rf_prediction': 'Psoriasis'}
# Active Features: ('joint_pain', 'cough') --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Psoriasis'}
# Active Features: ('joint_pain', 'high_fever') --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Psoriasis'}
# Active Features: ('joint_pain', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('joint_pain', 'breathlessness') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('joint_pain', 'sweating') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('joint_pain', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('joint_pain', 'indigestion') --> Prediction: {'dl_prediction': 'Osteoarthritis', 'rf_prediction': 'Psoriasis'}
# Active Features: ('joint_pain', 'headache') --> Prediction: {'dl_prediction': 'Osteoarthritis', 'rf_prediction': 'Paralysis (brain hemorrhage)'}
# Active Features: ('stomach_pain', 'acidity') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('stomach_pain', 'ulcers_on_tongue') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('stomach_pain', 'muscle_wasting') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'AIDS'}
# Active Features: ('stomach_pain', 'vomiting') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('stomach_pain', 'burning_micturition') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('stomach_pain', 'spotting_urination') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('stomach_pain', 'fatigue') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('stomach_pain', 'weight_gain') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('stomach_pain', 'anxiety') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('stomach_pain', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('stomach_pain', 'mood_swings') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('stomach_pain', 'weight_loss') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'GERD'}
# Active Features: ('stomach_pain', 'restlessness') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('stomach_pain', 'lethargy') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('stomach_pain', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('stomach_pain', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('stomach_pain', 'cough') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('stomach_pain', 'high_fever') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('stomach_pain', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('stomach_pain', 'breathlessness') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Heart Attack'}
# Active Features: ('stomach_pain', 'sweating') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('stomach_pain', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('stomach_pain', 'indigestion') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('stomach_pain', 'headache') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'ulcers_on_tongue') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'muscle_wasting') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('acidity', 'vomiting') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'burning_micturition') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('acidity', 'spotting_urination') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('acidity', 'fatigue') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'weight_gain') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'anxiety') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'mood_swings') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'weight_loss') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'restlessness') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'lethargy') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('acidity', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'cough') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'high_fever') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('acidity', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('acidity', 'breathlessness') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Heart Attack'}
# Active Features: ('acidity', 'sweating') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Heart Attack'}
# Active Features: ('acidity', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('acidity', 'indigestion') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Migraine'}
# Active Features: ('acidity', 'headache') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Migraine'}
# Active Features: ('ulcers_on_tongue', 'muscle_wasting') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'AIDS'}
# Active Features: ('ulcers_on_tongue', 'vomiting') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('ulcers_on_tongue', 'burning_micturition') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('ulcers_on_tongue', 'spotting_urination') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('ulcers_on_tongue', 'fatigue') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('ulcers_on_tongue', 'weight_gain') --> Prediction: {'dl_prediction': 'Osteoarthritis', 'rf_prediction': 'GERD'}
# Active Features: ('ulcers_on_tongue', 'anxiety') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('ulcers_on_tongue', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('ulcers_on_tongue', 'mood_swings') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('ulcers_on_tongue', 'weight_loss') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('ulcers_on_tongue', 'restlessness') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('ulcers_on_tongue', 'lethargy') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('ulcers_on_tongue', 'patches_in_throat') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'AIDS'}
# Active Features: ('ulcers_on_tongue', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('ulcers_on_tongue', 'cough') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('ulcers_on_tongue', 'high_fever') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'AIDS'}
# Active Features: ('ulcers_on_tongue', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('ulcers_on_tongue', 'breathlessness') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Heart Attack'}
# Active Features: ('ulcers_on_tongue', 'sweating') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'Heart Attack'}
# Active Features: ('ulcers_on_tongue', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('ulcers_on_tongue', 'indigestion') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('ulcers_on_tongue', 'headache') --> Prediction: {'dl_prediction': 'GERD', 'rf_prediction': 'GERD'}
# Active Features: ('muscle_wasting', 'vomiting') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'burning_micturition') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('muscle_wasting', 'spotting_urination') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('muscle_wasting', 'fatigue') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'weight_gain') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'anxiety') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'mood_swings') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'weight_loss') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'restlessness') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'lethargy') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'cough') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'high_fever') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('muscle_wasting', 'breathlessness') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'sweating') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'Heart Attack'}
# Active Features: ('muscle_wasting', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('muscle_wasting', 'indigestion') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('muscle_wasting', 'headache') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('vomiting', 'burning_micturition') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('vomiting', 'spotting_urination') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('vomiting', 'fatigue') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('vomiting', 'weight_gain') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('vomiting', 'anxiety') --> Prediction: {'dl_prediction': 'Hypoglycemia', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('vomiting', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('vomiting', 'mood_swings') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('vomiting', 'weight_loss') --> Prediction: {'dl_prediction': 'Jaundice', 'rf_prediction': 'Jaundice'}
# Active Features: ('vomiting', 'restlessness') --> Prediction: {'dl_prediction': 'Diabetes ', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('vomiting', 'lethargy') --> Prediction: {'dl_prediction': 'Chickenpox', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('vomiting', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('vomiting', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Diabetes ', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('vomiting', 'cough') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'GERD'}
# Active Features: ('vomiting', 'high_fever') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'AIDS'}
# Active Features: ('vomiting', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('vomiting', 'breathlessness') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('vomiting', 'sweating') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('vomiting', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('vomiting', 'indigestion') --> Prediction: {'dl_prediction': 'Peptic Ulcer Disease', 'rf_prediction': 'Peptic Ulcer Disease'}
# Active Features: ('vomiting', 'headache') --> Prediction: {'dl_prediction': 'Paralysis (brain hemorrhage)', 'rf_prediction': 'Paralysis (brain hemorrhage)'}
# Active Features: ('burning_micturition', 'spotting_urination') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('burning_micturition', 'fatigue') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('burning_micturition', 'weight_gain') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('burning_micturition', 'anxiety') --> Prediction: {'dl_prediction': 'Impetigo', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('burning_micturition', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('burning_micturition', 'mood_swings') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('burning_micturition', 'weight_loss') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('burning_micturition', 'restlessness') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('burning_micturition', 'lethargy') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('burning_micturition', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('burning_micturition', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('burning_micturition', 'cough') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('burning_micturition', 'high_fever') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('burning_micturition', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('burning_micturition', 'breathlessness') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('burning_micturition', 'sweating') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Heart Attack'}
# Active Features: ('burning_micturition', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('burning_micturition', 'indigestion') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('burning_micturition', 'headache') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('spotting_urination', 'fatigue') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('spotting_urination', 'weight_gain') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('spotting_urination', 'anxiety') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('spotting_urination', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('spotting_urination', 'mood_swings') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('spotting_urination', 'weight_loss') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('spotting_urination', 'restlessness') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('spotting_urination', 'lethargy') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('spotting_urination', 'patches_in_throat') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'AIDS'}
# Active Features: ('spotting_urination', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('spotting_urination', 'cough') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('spotting_urination', 'high_fever') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('spotting_urination', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('spotting_urination', 'breathlessness') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# ...
# Active Features: ('chills', 'burning_micturition', 'anxiety') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('chills', 'burning_micturition', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('chills', 'burning_micturition', 'mood_swings') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('chills', 'burning_micturition', 'weight_loss') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('chills', 'burning_micturition', 'restlessness') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('chills', 'burning_micturition', 'lethargy') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('chills', 'burning_micturition', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('chills', 'burning_micturition', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('chills', 'burning_micturition', 'cough') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('chills', 'burning_micturition', 'high_fever') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('chills', 'burning_micturition', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'burning_micturition', 'breathlessness') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('chills', 'burning_micturition', 'sweating') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Heart Attack'}
# Active Features: ('chills', 'burning_micturition', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'burning_micturition', 'indigestion') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('chills', 'burning_micturition', 'headache') --> Prediction: {'dl_prediction': 'Urinary Tract Infection', 'rf_prediction': 'Urinary Tract Infection'}
# Active Features: ('chills', 'spotting_urination', 'fatigue') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'weight_gain') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'anxiety') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'mood_swings') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'weight_loss') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'restlessness') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'lethargy') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'patches_in_throat') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'AIDS'}
# Active Features: ('chills', 'spotting_urination', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'cough') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'high_fever') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'spotting_urination', 'breathlessness') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'sweating') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'dehydration') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'spotting_urination', 'indigestion') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'spotting_urination', 'headache') --> Prediction: {'dl_prediction': 'Drug Reaction', 'rf_prediction': 'Drug Reaction'}
# Active Features: ('chills', 'fatigue', 'weight_gain') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'fatigue', 'anxiety') --> Prediction: {'dl_prediction': 'Hypoglycemia', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'fatigue', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'fatigue', 'mood_swings') --> Prediction: {'dl_prediction': 'Hyperthyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'fatigue', 'weight_loss') --> Prediction: {'dl_prediction': 'Jaundice', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'fatigue', 'restlessness') --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'fatigue', 'lethargy') --> Prediction: {'dl_prediction': 'Paralysis (brain hemorrhage)', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'fatigue', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('chills', 'fatigue', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Diabetes ', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'fatigue', 'cough') --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Bronchial Asthma'}
# Active Features: ('chills', 'fatigue', 'high_fever') --> Prediction: {'dl_prediction': 'Typhoid', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'fatigue', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'fatigue', 'breathlessness') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Bronchial Asthma'}
# Active Features: ('chills', 'fatigue', 'sweating') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('chills', 'fatigue', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'fatigue', 'indigestion') --> Prediction: {'dl_prediction': 'Malaria', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'fatigue', 'headache') --> Prediction: {'dl_prediction': 'Paralysis (brain hemorrhage)', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_gain', 'anxiety') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_gain', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_gain', 'mood_swings') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_gain', 'weight_loss') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_gain', 'restlessness') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_gain', 'lethargy') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_gain', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('chills', 'weight_gain', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Diabetes ', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_gain', 'cough') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_gain', 'high_fever') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_gain', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'weight_gain', 'breathlessness') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Heart Attack'}
# Active Features: ('chills', 'weight_gain', 'sweating') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Heart Attack'}
# Active Features: ('chills', 'weight_gain', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'weight_gain', 'indigestion') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_gain', 'headache') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'anxiety', 'cold_hands_and_feets') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'anxiety', 'mood_swings') --> Prediction: {'dl_prediction': 'Hyperthyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'anxiety', 'weight_loss') --> Prediction: {'dl_prediction': 'Hypoglycemia', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'anxiety', 'restlessness') --> Prediction: {'dl_prediction': 'Hypoglycemia', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'anxiety', 'lethargy') --> Prediction: {'dl_prediction': 'Hypoglycemia', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'anxiety', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('chills', 'anxiety', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Hypoglycemia', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'anxiety', 'cough') --> Prediction: {'dl_prediction': 'Hypoglycemia', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'anxiety', 'high_fever') --> Prediction: {'dl_prediction': 'Malaria', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'anxiety', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'anxiety', 'breathlessness') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('chills', 'anxiety', 'sweating') --> Prediction: {'dl_prediction': 'Heart Attack', 'rf_prediction': 'Heart Attack'}
# Active Features: ('chills', 'anxiety', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'anxiety', 'indigestion') --> Prediction: {'dl_prediction': 'Malaria', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'anxiety', 'headache') --> Prediction: {'dl_prediction': 'Hypoglycemia', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'cold_hands_and_feets', 'mood_swings') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'cold_hands_and_feets', 'weight_loss') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'cold_hands_and_feets', 'restlessness') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'cold_hands_and_feets', 'lethargy') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'cold_hands_and_feets', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('chills', 'cold_hands_and_feets', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Diabetes ', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'cold_hands_and_feets', 'cough') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'cold_hands_and_feets', 'high_fever') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'cold_hands_and_feets', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'cold_hands_and_feets', 'breathlessness') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Heart Attack'}
# Active Features: ('chills', 'cold_hands_and_feets', 'sweating') --> Prediction: {'dl_prediction': 'Malaria', 'rf_prediction': 'Heart Attack'}
# Active Features: ('chills', 'cold_hands_and_feets', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'cold_hands_and_feets', 'indigestion') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'cold_hands_and_feets', 'headache') --> Prediction: {'dl_prediction': 'Hypothyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'mood_swings', 'weight_loss') --> Prediction: {'dl_prediction': 'Hyperthyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'mood_swings', 'restlessness') --> Prediction: {'dl_prediction': 'Hyperthyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'mood_swings', 'lethargy') --> Prediction: {'dl_prediction': 'Hyperthyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'mood_swings', 'patches_in_throat') --> Prediction: {'dl_prediction': 'AIDS', 'rf_prediction': 'AIDS'}
# Active Features: ('chills', 'mood_swings', 'irregular_sugar_level') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'mood_swings', 'cough') --> Prediction: {'dl_prediction': 'Bronchial Asthma', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'mood_swings', 'high_fever') --> Prediction: {'dl_prediction': 'Hyperthyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'mood_swings', 'sunken_eyes') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'mood_swings', 'breathlessness') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Heart Attack'}
# Active Features: ('chills', 'mood_swings', 'sweating') --> Prediction: {'dl_prediction': 'Hyperthyroidism', 'rf_prediction': 'Heart Attack'}
# Active Features: ('chills', 'mood_swings', 'dehydration') --> Prediction: {'dl_prediction': 'Gastroenteritis', 'rf_prediction': 'Gastroenteritis'}
# Active Features: ('chills', 'mood_swings', 'indigestion') --> Prediction: {'dl_prediction': 'Allergy', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'mood_swings', 'headache') --> Prediction: {'dl_prediction': 'Hyperthyroidism', 'rf_prediction': 'Allergy'}
# Active Features: ('chills', 'weight_loss', 'restlessness') --> Prediction: {'dl_prediction': 'Diabetes ', 'rf_prediction': 'Allergy'}
